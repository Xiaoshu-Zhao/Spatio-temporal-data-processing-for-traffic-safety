# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

# %matplotlib inline

# %%
df = pd.read_csv('data/twitter_data_sample.csv', index_col = 0)
df.head()
# Out:
#               user             location  \
# 0   BstKept_Secret  Your wildest dreams
# 1        fer_schez        Manhattan, NY
# 2       GuiRequiel                  NaN
# 3  Restore_NewYork             New York
# 4     cee_jay_2016                  NaN
#
#                                                  txt              user_id  \
# 0  RT @JUSMITHOUGHTS1: Fellas your lady send you ...            386971636
# 1  #NowPlaying  #AppleMusic \n🔊 Rolling In the D...             67189705
# 2  RT @FieldYates: Happy 40th birthday, McLovin. ...            186896873
# 3  RT @CurtisSliwa: It is time to kick lying poli...  1104621094122737664
# 4  RT @malcolmkenyatta: #Pride is protecting the ...           4614153192
#
#               tweet_id                 date  geo
# 0  1400603202135941120  2021-06-03 23:59:59  NaN
# 1  1400603202031063043  2021-06-03 23:59:59  NaN
# 2  1400603201699827716  2021-06-03 23:59:59  NaN
# 3  1400603201683001351  2021-06-03 23:59:59  NaN
# ...

# %%
df.loc[df.geo.notnull(), :]
# Out:
#                   user                  location  \
# 405      CROSSMARKJobs                 Plano, TX
# 456     JeffreyHines80                       NaN
# 1085             511NY            New York State
# 1086             511NY            New York State
# 1105             511NY            New York State
# ...                ...                       ...
# 58598       GAGA_glitz        NJ/Mons†er Kingdom
# 59067   511NYMidHudson                 Catskills
# 59112  CTDOT_Statewide               Connecticut
# 59113  CTDOT_District3  Southwestern Connecticut
# 59938  pop_amargaritav          Connecticut, USA
#
#                                                      txt             user_id  \
# 405    Can you recommend anyone for this job? RETAIL ...            36039488
# 456    I’m not a big fan of oatmeal except when it is...  717863903305326592
# 1085   Cleared: Incident on #HutchinsonRiverParkwayWe...            50706690
# ...

# %%
user_with_geo = pd.unique(df_geo.user)
number_of_user_with_geo = len(pd.unique(df_geo.user))
print(user_with_geo)
print(number_of_user_with_geo)
# Out:
# ['CROSSMARKJobs' 'JeffreyHines80' '511NY' '511NYMidHudson'
#  'Manhattanpeachy' 'robbwil1' 'CTDOT_District1' 'CTDOT_Statewide'
#  'shellfaber6' 'XclusiveArrival' 'HalterTop34' 'kyny889' 'iamnatemyles'
#  'rocdabroski' 'josephmariko' 'chrisiestyles' 'RockStarr65'
#  'coachmlewis33' 'TotalTrafficPHL' 'BlazeMusicNet' 'LsarowarRBLX2nd'
#  'BGWritesStuff' 'BKSoulStew' 'j_rakowski' 'WWFarmersMarket'
#  'DeWittGodfrey' 'rchiarellajewel' 'NWS_MountHolly' 'NWSSevereTstorm'
#  'Devilsfan79' 'algattullo' 'iembot_phi' 'yankee32879' 'adampicz'
#  'KennethFerrone' 'dhsbaseballnj' 'AnthonyPPinto' '5feetoffashion' 'Grafh'
#  'DJBEEBLACK' 'hrhwe1032' 'RaquelCion' 'BrewPubExplorer' 'lincolnwrites'
#  'giordanobc' 'NomInNY' 'TAsterisk' 'RobHBedford' 'imdjencore'
#  'everytract' 'stevelauro' 'M97Cos' 'choppy2984' 'Majikonline'
#  'JohnnyBarfly' 'RoyRuger' 'RRWhiskySpirits' 'harisamin' 'lentaminen'
#  'Katluck125' 'TotalTrafficNYC' 'SsmBoutique40' 'billfelty' 'BienRealty'
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ut